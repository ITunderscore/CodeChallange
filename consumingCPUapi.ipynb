# %%
#####################
#     BY
# Isaac Gazimbe
####################

import requests
import json

#consuming an api
response = requests.get('https://robotstakeover20210903110417.azurewebsites.net/robotcpu')
#json format
print(response.json())
print('---Human redable format---')
#human redable formart
for i in range(len(response.json())):
    print('category: ', response.json()[i]['category'])
    print('serialNumber: ', response.json()[i]['serialNumber'])
    print('model: ', response.json()[i]['model'])
    print('manufacturedDate: ', response.json()[i]['manufacturedDate'])
    print('-----------------')
# Out:
# [{'model': '01Z1L', 'serialNumber': 'VRD2HJPME2EYI7A', 'manufacturedDate': '2021-10-20T05:24:14.878964+00:00', 'category': 'Land'}, {'model': '0K8SG', 'serialNumber': '4F9Z0QLJ22GA812', 'manufacturedDate': '2021-12-04T05:24:14.879036+00:00', 'category': 'Land'}, {'model': '0WYY1', 'serialNumber': '7V1QZRMI8KGX5MP', 'manufacturedDate': '2021-10-31T05:24:14.8789899+00:00', 'category': 'Flying'}, {'model': '14KQN', 'serialNumber': '0WFRDYOFVM6QWE1', 'manufacturedDate': '2021-11-16T05:24:14.8790074+00:00', 'category': 'Land'}, {'model': '24XT2', 'serialNumber': 'PMXXMDPURBEV7V7', 'manufacturedDate': '2021-11-18T05:24:14.8790095+00:00', 'category': 'Flying'}, {'model': '4T7JJ', 'serialNumber': 'F59DBN2YSOTSDZV', 'manufacturedDate': '2021-11-28T05:24:14.8790296+00:00', 'category': 'Land'}, {'model': '5RF2H', 'serialNumber': 'CLTLCJ237K8KTZN', 'manufacturedDate': '2021-11-12T05:24:14.879003+00:00', 'category': 'Flying'}, {'model': '6DNFL', 'serialNumber': 'VPQVNR57S9IRUHT', 'manufacturedDat
# ...
